# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
from iexfinance.stocks import Stock, get_historical_data
from iexfinance.refdata import get_symbols
import os
key = os.getenv('IEX_TOKEN')
plt.rcParams['figure.figsize'] = [20, 20]

# %%
class Signals():
    def __init__(self, symbol, start, end):
        self.symbol = symbol
        self.start = start
        self.end = end
        self.data = get_historical_data(self.symbol, self.start, self.end, output_format='pandas')
        self.data['avg'] = (self.data['close'] + self.data['low'] + self.data['high']) / 3
    
    def all_indicators(self, ndays_ema_short=12, ndays_ema_long=26, macd_ndays=9, cci_ndays=20):
        ema_short = self.data['avg'].ewm(span=ndays_ema_short).mean()
        ema_long = self.data['avg'].ewm(span=ndays_ema_long).mean()
        
        sma = self.data['avg'].rolling(window=cci_ndays).mean()
        std = self.data['avg'].rolling(window=cci_ndays).std()
        cci = (self.data['avg'] - sma) / (0.015 * std)
        
        macd = ema_short - ema_long
        signal_line_macd = macd.ewm(span=macd_ndays).mean()
        
        plt.subplot(311)
        plt.plot(self.data['avg'], label=self.symbol, color='green')
        plt.plot(ema_short, label='EMA {0} days'.format(ndays_ema_short), color='blue')
        plt.plot(ema_long, label='EMA {0} days'.format(ndays_ema_long), color='red')
        plt.legend()
        
        plt.subplot(312)
        plt.plot(macd, label=self.symbol + ' macd', color='blue')
        plt.plot(signal_line_macd, label='signal line', color='green')
        plt.legend()
        
        plt.subplot(313)
        plt.plot(self.data['avg'].index, [100]*len(self.data['close'].index), label='overpriced', linestyle=':', color='red')
        plt.plot(self.data['avg'].index, [-100]*len(self.data['close'].index), label='underpriced', linestyle=':', color='blue')
        plt.plot(cci, label='cci', color='magenta')   
        plt.legend()
        
        plt.show()
        
    def SMA(self, window_start, window_end):
        # Simple Moving Average
        short = self.data['close'].rolling(window=window_start).mean()
        long = self.data['close'].rolling(window=window_end).mean()
        plt.plot(short, label='15 day SMA')
        plt.plot(long, label='30 day SMA')
        plt.plot(self.data['close'], label='close', color='green')
        plt.legend()
        plt.show()
    
    def EMA(self, span_start, span_end):
        # Exponential Moving Average
        short = self.data['close'].ewm(span=span_start).mean()
        long = self.data['close'].ewm(span=span_end).mean()
        plt.plot(short, label='15 day SMA')
        plt.plot(long, label='30 day SMA')
        plt.plot(self.data['close'], label='close', color='green')
        plt.legend()
        plt.show()
    
    def MACD(self, window_start, window_end, window_macd):
        # Moving Average Convergence Divergence
        short = self.data['close'].ewm(span=window_start).mean()
        long = self.data['close'].ewm(span=window_end).mean()
        macd = short - long
        smoothed = macd.ewm(span=window_macd, adjust=False).mean()
        plt.plot(macd, label='macd', color='magenta')
        plt.plot(smoothed, label='smoothed', color='blue')
        plt.legend()
        plt.show()
    
    def macd_2plot(self, window_start, window_end):
        # Moving Average Convergence Divergence
        exp1 = self.data['close'].ewm(span=window_start).mean()
        exp2 = self.data['close'].ewm(span=window_end).mean()
        macd = exp1 - exp2
        
        plt.plot(macd, label='macd', color='magenta')        
        plt.plot(self.data['close'], label='close', color='green')
        plt.legend()
        plt.show()
        
        plt.subplot(211)
        plt.plot(macd, label='macd', color='magenta') 
        plt.legend()
        plt.show()
        
        plt.subplot(212)
        plt.plot(self.data['close'], label='close', color='green')
        plt.legend()
        plt.show()
        
    def CCI(self, ndays):
        # Commodity Channel Index
        sma = self.data['close'].rolling(window=ndays).mean()
        std = self.data['close'].rolling(window=ndays).std()
        cci = (self.data['close'] - sma) / (0.015 * std)
        
        plt.subplot(211)
        plt.plot(self.data['close'], label='close', color='green')
        plt.legend()
        
        plt.subplot(212)
        plt.plot(self.data['close'].index, [100]*len(self.data['close'].index), linestyle=':', color='blue')
        plt.plot(self.data['close'].index, [-100]*len(self.data['close'].index), linestyle=':', color='blue')
        plt.plot(cci, label='cci', color='magenta')
        plt.legend()
        plt.show()

# %%
g = Signals('INTC', start=datetime(2018, 1, 1), end=datetime(2019,11,25))
g.all_indicators()
